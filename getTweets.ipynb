# %%
import tweepy
import json
from pprint import pprint
import time
import csv

# %%
with open('package.json', 'r') as file:
    keys = json.load(file)

client = tweepy.Client(bearer_token=keys['Bearer_Token'])

# %%
with open('leftwingaccounts.txt', 'r') as file:
    accounts = file.read().split('\n')

with open('tweets.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    for user in accounts:
        print(user)
        try:
          user = client.get_user(username=user)
          if user is None:
            continue
          user = user.data.data
          likedTweets = client.get_liked_tweets(user['id'], max_results=100)
          tweets = client.get_users_tweets(user['id'], max_results=100)
          for tweet in likedTweets.data:
            writer.writerow([tweet.text])
          for tweet in tweets.data:
            writer.writerow([tweet.text])
        except Exception as e:
            print(e)
            if 'Requests' in str(e):
                print('Sleeping for 15 min')
                time.sleep(900)  # sleep 15 min if too many requests
# Out:
# RazzledDazzler
# RazzledDazzler
# tuple indices must be integers or slices, not str
# Cupids_Psyche
# Cupids_Psyche
# tuple indices must be integers or slices, not str
# jocelle_smith
# jocelle_smith
# tuple indices must be integers or slices, not str
# susievikes1
# susievikes1
# tuple indices must be integers or slices, not str
# VaushV
# VaushV
# tuple indices must be integers or slices, not str
# daaanker
# daaanker
# tuple indices must be integers or slices, not str
# SocDoneLeft
# SocDoneLeft
# tuple indices must be integers or slices, not str
# punishedmother
# punishedmother
# tuple indices must be integers or slices, not str
# xaviers_online
# xaviers_online
# tuple indices must be integers or slices, not str
# ShinjiTheCuban
# ShinjiTheCuban
# tuple indices must be integers or slices, not str
# CopingTankie
# CopingTankie
# tuple indices must be integers or slices, not str
# joss_prior
# joss_prior
# tuple indices must be integers or slices, not str
# RobertforKansas
# ...
